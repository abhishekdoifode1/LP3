# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn import preprocessing

# %%
df = pd.read_csv('uber.csv')

# %%
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [200000 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df = df.drop(['Unnamed: 0', 'key'], axis=1)

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce')

# %%
df= df.assign(
second = df.pickup_datetime.dt.second,
minute = df.pickup_datetime.dt.minute,
hour = df.pickup_datetime.dt.hour,
day= df.pickup_datetime.dt.day,
month = df.pickup_datetime.dt.month,
year = df.pickup_datetime.dt.year,
dayofweek = df.pickup_datetime.dt.dayofweek
)
df = df.drop('pickup_datetime',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_longitude   199999 non-null  float64
#  2   pickup_latitude    199999 non-null  float64
#  3   dropoff_longitude  199999 non-null  float64
#  4   dropoff_latitude   199999 non-null  float64
#  5   passenger_count    199999 non-null  int64
#  6   second             199999 non-null  int64
#  7   minute             199999 non-null  int64
#  8   hour               199999 non-null  int64
#  9   day                199999 non-null  int64
#  10  month              199999 non-null  int64
#  11  year               199999 non-null  int64
#  12  dayofweek          199999 non-null  int64
# dtypes: float64(5), int64(8)
# memory usage: 21.4 MB

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek
# 0          3
# 1          4
# 2          0
# 3          4
# 4          3

# %%
incorrect_coordinates = df.loc[
(df.pickup_latitude > 90) |(df.pickup_latitude < -90) |
(df.dropoff_latitude > 90) |(df.dropoff_latitude < -90) |
(df.pickup_longitude > 180) |(df.pickup_longitude < -180) |
(df.dropoff_longitude > 90) |(df.dropoff_longitude < -90)
]
df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
def distance_transform(longitude1, latitude1, longitude2, latitude2):
    long1, lati1, long2, lati2 = map(np.radians, [longitude1, latitude1, longitude2, latitude2])
    dist_long = long2 - long1
    dist_lati = lati2 - lati1
    a = np.sin(dist_lati/2)**2 + np.cos(lati1) * np.cos(lati2) * np.sin(dist_long/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) * 6371
# long1,lati1,long2,lati2 = longitude1[pos],latitude1[pos],longitude2[pos],latitude2[pos]
# c = sqrt((long2 - long1) ** 2 + (lati2 - lati1) ** 2)asin 
 
    return c

# %%
df['Distance'] = distance_transform(
df['pickup_longitude'],
df['pickup_latitude'],
df['dropoff_longitude'],
df['dropoff_latitude']
)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek  Distance
# 0          3  1.683323
# 1          4  2.457590
# 2          0  5.036377
# 3          4  1.661683
# 4          3  4.475450

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
plt.figure(figsize=(20,12))
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
df.drop(df[df['Distance']>=60].index, inplace = True)
df.drop(df[df['fare_amount']  0].index, inplace = True)
df.drop(df[(df['fare_amount']>100) & (df['Distance']<1)].index, inplace = True )
df.drop(df[(df['fare_amount']<100) & (df['Distance']>100)].index, inplace = True )
# Out:
#   File "<ipython-input-21-5c47cdb6af3f>", line 2
#     df.drop(df[df['fare_amount']  0].index, inplace = True)
#                                   ^
# SyntaxError: invalid syntax

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
corr = df.corr()
corr.style.background_gradient(cmap='BuGn')
# Out:
# <style  type="text/css" >
# #T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col1,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col2,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col3,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col4,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row13_col13{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col1,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col1,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col1{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col2,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col2,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col3,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col3,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col3{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col4,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col3,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col4{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col5{
#             background-color:  #dbf1f1;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row13_col5{
#             background-color:  #ddf2f3;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col2,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col4,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col1,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col3,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col8{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col10{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col1,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col9{
#             background-color:  #f5fbfc;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row13_col11{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col11{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col12{
#             background-color:  #ebf7fa;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row0_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col10{
#             background-color:  #e9f7fa;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col0{
#             background-color:  #f3fafc;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col3{
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col4{
#             background-color:  #f2fafc;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col13,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col5,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row13_col6{
#             background-color:  #dcf2f2;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col6,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col6{
#             background-color:  #dff3f4;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row2_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row4_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row10_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col7,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row13_col7{
#             background-color:  #f6fcfd;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col2,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row8_col9,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row9_col0,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row12_col9{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col11,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col10,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row5_col12{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row1_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row3_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row6_col12,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row7_col8,#T_bc29540a_6a76_11ed_93cb_085bd6db0ce4row11_co

# %%
X = df['Distance'].values.reshape(-1, 1) #Independent Variable
y = df['fare_amount'].values.reshape(-1, 1) #Dependent Variable

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)
x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.38981971]
#  [-0.36962123]
#  [ 0.15553925]
#  ...
#  [ 1.97340244]
#  [ 0.31712709]
#  [ 0.27673013]]
# [[-0.05006226]
#  [-0.04804048]
#  [-0.04130672]
#  ...
#  [-0.02090285]
#  [-0.04521482]
#  [-0.04031078]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)
print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.00
# Test set score: 0.0003219

# %%
y_pred = l_reg.predict(X_test)
result = pd.DataFrame()
result[['Actual']] = y_test
result[['Predicted']] = y_pred
result.sample(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-4fd8c029be04> in <module>
#       1 y_pred = l_reg.predict(X_test)
#       2 result = pd.DataFrame()
# ----> 3 result[['Actual']] = y_test
#       4 result[['Predicted']] = y_pred
#       5 result.sample(10)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3035             self._setitem_frame(key, value)
#    3036         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3037             self._setitem_array(key, value)
#    3038         else:
#    3039             # set column
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3070                 )[1]
#    3071                 self._check_setitem_copy()
# -> 3072                 self.iloc._setitem_with_indexer((slice(None), indexer), value)
#    3073
#    3074     def _setitem_frame(self, key, value):
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1800             # actually do the set
#    1801             self.obj._consolidate_inplace()
# -> 1802             self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1803             self.obj._maybe_update_cacher(clear=True)
#    1804
#
# C:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in setitem(self, indexer, value)
#     532
#     533     def setitem(self, indexer, value) -> "BlockManager":
# --> 534         return self.apply("setitem", indexer=indexer, value=value)
#     535
#     536     def putmask(
#
# C:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in setitem(self, indexer, value)
#     889         # set
#     890         else:
# --> 891             values[indexer] = value
#     892
#     893         if transpose:
#
# ValueError: shape mismatch: value array of shape (40000,1) could not be broadcast to indexing result of shape (1,0)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute % Error:', metrics.
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.6096976190196316
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-d5fdbe9056b7> in <module>
#       1 print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# ----> 2 print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
#       3 print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
#       4 print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
#       5 print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred)))
#
# AttributeError: module 'sklearn.metrics' has no attribute 'mean_absolute_percentage_error'

# %%
plt.subplot(2, 2, 1)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.title("Fare vs Distance (Training Set)")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.subplot(2, 2, 2)
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.title("Fare vs Distance (Test Set)")
plt.tight_layout()
plt.show()

# %%
cols = ['Model', 'RMSE', 'R-Squared']
# create a empty dataframe of the colums
# columns: specifies the columns to be selected
result_tabulation = pd.DataFrame(columns = cols)
# compile the required information
linreg_metrics = pd.DataFrame([[
"Linear Regresion model",
np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
np.sqrt(metrics.r2_score(y_test, y_pred))
]], columns = cols)
result_tabulation = pd.concat([result_tabulation, linreg_metrics], ignore_index=True)
result_tabulation
# Out:
#                     Model      RMSE  R-Squared
# 0  Linear Regresion model  1.015756   0.017943

# %%
rf_reg = RandomForestRegressor(n_estimators=100, random_state=10)
# fit the regressor with training dataset
rf_reg.fit(X_train, y_train)
# Out:
# <ipython-input-32-5abbb8c019d9>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(X_train, y_train)

# %%
# predict the values on test dataset using predict()
y_pred_RF = rf_reg.predict(X_test)
result = pd.DataFrame()
result[['Actual']] = y_test
result['Predicted'] = y_pred_RF
result.sample(10)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_RF))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred_RF))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_RF))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred_RF)))

# %%
# Build scatterplot
plt.scatter(X_test, y_test, c = 'b', alpha = 0.5, marker = '.', label = 'Real')
plt.scatter(X_test, y_pred_RF, c = 'r', alpha = 0.5, marker = '.', label = 'Predicted')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.grid(color = '#D3D3D3', linestyle = 'solid')
plt.legend(loc = 'lower right')
plt.tight_layout()
plt.show()

# %%
# compile the required information
random_forest_metrics = pd.DataFrame([[
"Random Forest Regressor model",
np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)),
np.sqrt(metrics.r2_score(y_test, y_pred_RF))
]], columns = cols)
result_tabulation = pd.concat([result_tabulation, random_forest_metrics], ignore_index=True)
result_tabulation
